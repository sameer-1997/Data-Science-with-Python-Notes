# %%
#Function
def add(n1,n2):
    return n1+n2

# %%
add(1,12)
# Out:
# 13

# %%
#Lambda Expression
#-----------params---return logic
add1 = lambda n1,n2: n1+n2

#Lambda expression cannot have more than one liner logic

# %%
add1(3,2)
# Out:
# 5
